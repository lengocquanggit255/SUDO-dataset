# %%
# !huggingface-cli login --token 
import wandb

# Login using your API token
wandb.login(key="")
wandb.init(project="XcomBartLargeLoraOM")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `Dagoras` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Dagoras`
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lengocquang2554 (quang123). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250922_103109-yrvcoa8o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run silvery-cherry-17
# wandb: ⭐️ View project at https://wandb.ai/quang123/XcomBartLargeLoraOM
# wandb: 🚀 View run at https://wandb.ai/quang123/XcomBartLargeLoraOM/runs/yrvcoa8o
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/quang123/XcomBartLargeLoraOM/runs/yrvcoa8o?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from datasets import load_dataset
import torch
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
import json
from transformers import logging
logging.set_verbosity_error()


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

checkpoint = "facebook/bart-large"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %% [markdown]
# # Preprocess

# %%
from datasets import DatasetDict,load_dataset


# Load the dataset
data = load_dataset("lengocquangLAB/beer-com-reviews")

# Lấy 100 dòng đầu tiên từ các split 'train' và 'test' sử dụng select()
# train_subset = data['train'].select(range(200))
# test_subset = data['test'].select(range(200))
# val_subset = data['validation'].select(range(50))

train_subset = data['train']
test_subset = data['test']
val_subset = data['validation']


# Merge the subsets back into a DatasetDict
data = DatasetDict({
    'train': train_subset,
    'test': test_subset,
    'val' : val_subset
})
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/977k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/142k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/133k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3320 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/410 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/420 [00:00<?, ? examples/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['profileName', 'beerName_1', 'beerId_1', 'beerABV_1', 'beerStyle_1', 'reviewText_1', 'appearanceRate_1', 'aromaRate_1', 'palateRate_1', 'tasteRate_1', 'beerName_2', 'beerId_2', 'beerABV_2', 'beerStyle_2', 'reviewText_2', 'appearanceRate_2', 'aromaRate_2', 'palateRate_2', 'tasteRate_2', 'appearance', 'aroma', 'palate', 'taste'],
#         num_rows: 3320
#     })
#     test: Dataset({
#         features: ['profileName', 'beerName_1', 'beerId_1', 'beerABV_1', 'beerStyle_1', 'reviewText_1', 'appearanceRate_1', 'aromaRate_1', 'palateRate_1', 'tasteRate_1', 'beerName_2', 'beerId_2', 'beerABV_2', 'beerStyle_2', 'reviewText_2', 'appearanceRate_2', 'aromaRate_2', 'palateRate_2', 'tasteRate_2', 'appearance', 'aroma', 'palate', 'taste'],
#         num_rows: 410
#     })
#     val: Dataset({
#         features: ['profileName', 'beerName_1', 'beerId_1', 'beerABV_1', 'beerStyle_1', 'reviewText_1', 'appearanceRate_1', 'aromaRate_1', 'palateRate_1', 'tasteRate_1', 'beerName_2', 'beerId_2', 'beerABV_2', 'beerStyle_2', 'reviewText_2', 'appearanceRate_2', 'aromaRate_2', 'palateRate_2', 'tasteRate_2', 'appearance', 'aroma', 'palate', 'taste'],
#         num_rows: 420
#     })
# })

# %%
data['train']['reviewText_1'][0]
data['train']['reviewText_2'][0]
# Out:
# 'An excellent Belgian styled ale. Pours a medium golden hue complete with very small, champagne like bubbles, and a tight foamy head. Reminscent of the strong belgian beers likes Chimay White or fellow North American brew, the Unibroue Eau Benite. Incredbly smooth tasting considering its crisp, hoppy characteristics, all of which make this a great choice for those lazy afternoons.'

# %%
def preprocess_function(examples):
    # Format input
    formatted_inputs = [
        f"Compare {rev1} [SEP] {rev2}"
        for rev1, rev2 in zip(examples["reviewText_1"], examples["reviewText_2"])
    ]

    # Tokenize inputs
    model_inputs = tokenizer(
        formatted_inputs,
        max_length=880,
        truncation=True,
        padding="max_length"
    )

    labels = []
    label_dicts = []

    for app, aro, pal, tas in zip(
        examples["appearance"], examples["aroma"], examples["palate"], examples["taste"]
    ):
        label_dict = {
            "appearance": app,
            "aroma": aro,
            "palate": pal,
            "taste": tas,
        }
        label_dicts.append(label_dict)

        # Chuỗi phẳng theo format yêu cầu
        label_str = (
            f"appearance:{int(app) if app is not None else 'None'},"
            f"aroma:{int(aro) if aro is not None else 'None'},"
            f"palate:{int(pal) if pal is not None else 'None'},"
            f"taste:{int(tas) if tas is not None else 'None'}"
        )

        labels.append(label_str)

    # Tokenize labels
    labels_tokenized = tokenizer(
        text_target=labels,
        max_length=22,
        truncation=True,
        padding="max_length"
    )

    model_inputs["labels"] = labels_tokenized["input_ids"]
    model_inputs["label_dict"] = label_dicts
    return model_inputs


# Map lại
tokenized_data = data.map(preprocess_function, batched=True)

sample = tokenized_data["train"][0]
print("Raw:", sample["label_dict"])
print("Label decoded:", tokenizer.decode(sample["labels"], skip_special_tokens=False))
print("Raw ids:", sample["labels"])
# Out:
# Map:   0%|          | 0/3320 [00:00<?, ? examples/s]
# Map:   0%|          | 0/410 [00:00<?, ? examples/s]
# Map:   0%|          | 0/420 [00:00<?, ? examples/s]
# Raw: {'appearance': 1.0, 'aroma': None, 'palate': None, 'taste': -1.0}
# Label decoded: <s>appearance:1,aroma:None,palate:None,taste:-1</s><pad>
# Raw ids: [0, 3340, 39122, 35, 134, 6, 271, 4982, 35, 29802, 6, 18239, 877, 35, 29802, 6, 90, 14631, 36185, 134, 2, 1]

# %%
tokenized_data = tokenized_data.select_columns(['input_ids', 'attention_mask', 'labels'])

tokenized_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 3320
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 410
#     })
#     val: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 420
#     })
# })

# %%
from transformers import DataCollatorForSeq2Seq
data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=checkpoint,   # hoặc để None cũng được, nhưng để vào thì collator xử lý padding chính xác hơn
    padding=True,
    return_tensors="pt" # để HuggingFace Trainer trả tensor PyTorch
)

# %% [markdown]
# # Test

# %%
import json
from collections import defaultdict

def PRF(pred_texts, label_texts, is_test=True):
    aspects = ["appearance", "aroma", "palate", "taste"]
    positive_labels = [-1, 0, 1]
    negative_label = None
    default_pred = {aspect: None for aspect in aspects}

    # --- Parse ---
    def parse_flat_kv(text):
        try:
            if not text or not text.strip():
                return default_pred
            text = text.strip()
            # Tách theo dấu phẩy, sau đó split theo dấu :
            pairs = [seg.strip() for seg in text.split(",") if seg.strip()]
            result_dict = default_pred.copy()
            for pair in pairs:
                if ":" not in pair:
                    continue
                key, val = pair.split(":", 1)
                key = key.strip()
                val = val.strip()
                if val.lower() == "null":
                    value = None
                else:
                    try:
                        value = float(val)
                    except ValueError:
                        value = None
                if key in aspects and (value in positive_labels or value is None):
                    result_dict[key] = value
            return result_dict
        except Exception:
            return default_pred

    pred = [parse_flat_kv(p) for p in pred_texts]
    label = [parse_flat_kv(l) for l in label_texts]

    # --- Helper ---
    def compute_tp_fp_fn(true_labels, pred_labels):
        tp, fp, fn = defaultdict(int), defaultdict(int), defaultdict(int)
        for true, pred in zip(true_labels, pred_labels):
            if true == pred:
                if true in positive_labels:
                    tp[true] += 1
            else:
                if true in positive_labels and pred is negative_label:
                    fn[true] += 1
                elif true is negative_label and pred in positive_labels:
                    fp[pred] += 1
                elif true in positive_labels and pred in positive_labels:
                    fn[true] += 1
                    fp[pred] += 1
        return tp, fp, fn

    def prf_from_tp_fp_fn(tp, fp, fn):
        # micro
        total_tp, total_fp, total_fn = sum(tp.values()), sum(fp.values()), sum(fn.values())
        precision_micro = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
        recall_micro = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
        f1_micro = 2 * precision_micro * recall_micro / (precision_micro + recall_micro) if (precision_micro + recall_micro) > 0 else 0

        # macro
        precisions, recalls, f1s = [], [], []
        for cls in positive_labels:
            tpc, fpc, fnc = tp[cls], fp[cls], fn[cls]
            prec = tpc / (tpc + fpc) if (tpc + fpc) > 0 else 0
            rec = tpc / (tpc + fnc) if (tpc + fnc) > 0 else 0
            f1c = 2 * prec * rec / (prec + rec) if (prec + rec) > 0 else 0
            precisions.append(prec)
            recalls.append(rec)
            f1s.append(f1c)
        precision_macro = sum(precisions) / len(precisions)
        recall_macro = sum(recalls) / len(recalls)
        f1_macro = sum(f1s) / len(f1s)

        return {
            "precision_macro_class": precision_macro,
            "recall_macro_class": recall_macro,
            "f1_macro_class": f1_macro,
            "precision_micro": precision_micro,
            "recall_micro": recall_micro,
            "f1_micro": f1_micro,
        }

    # --- Global (flatten all aspects) ---
    true_labels_all = [label[i][aspect] for i in range(len(label)) for aspect in aspects]
    pred_labels_all = [pred[i][aspect] for i in range(len(pred)) for aspect in aspects]
    tp_all, fp_all, fn_all = compute_tp_fp_fn(true_labels_all, pred_labels_all)
    global_scores = prf_from_tp_fp_fn(tp_all, fp_all, fn_all)

    # --- Per Aspect ---
    aspect_scores = {}
    for aspect in aspects:
        true_labels = [l[aspect] for l in label]
        pred_labels = [p[aspect] for p in pred]
        tp, fp, fn = compute_tp_fp_fn(true_labels, pred_labels)
        aspect_scores[aspect] = prf_from_tp_fp_fn(tp, fp, fn)

    # --- Macro per Aspect (trung bình các aspect) ---
    macro_precision_aspect = sum(v["precision_macro_class"] for v in aspect_scores.values()) / len(aspect_scores)
    macro_recall_aspect = sum(v["recall_macro_class"] for v in aspect_scores.values()) / len(aspect_scores)
    macro_f1_aspect = sum(v["f1_macro_class"] for v in aspect_scores.values()) / len(aspect_scores)

    # --- Return ---
    result = {
        **global_scores,
        "precision_macro_aspect": macro_precision_aspect,
        "recall_macro_aspect": macro_recall_aspect,
        "f1_macro_aspect": macro_f1_aspect,
        "per_aspect": aspect_scores
    }
    return result

# %%
import numpy as np

def validate_tokens(tokens):
    tokens = np.array(tokens) if not isinstance(tokens, np.ndarray) else tokens
    pad_token_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else 0
    tokens = np.where(tokens < 0, pad_token_id, tokens)  # Replace negative IDs
    return tokens


def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    
    predictions = validate_tokens(predictions)
    labels = validate_tokens(labels)
    
    pred_texts = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    label_texts = tokenizer.batch_decode(labels, skip_special_tokens=True)

    print("=== First 5 pred_texts ===")
    for i, t in enumerate(pred_texts[:5]):
        print(f"{i+1}: {t}")
    
    print("\n=== First 5 label_texts ===")
    for i, t in enumerate(label_texts[:5]):
        print(f"{i+1}: {t}")

    
    # Tính toàn bộ metrics
    metrics = PRF(pred_texts, label_texts)

    # Gom hết vào dict trả về
    result = {
        # --- Global scores ---
        "micro_precision": metrics["precision_micro"],
        "micro_recall": metrics["recall_micro"],
        "micro_f1": metrics["f1_micro"],
        "macro_precision_class": metrics["precision_macro_class"],
        "macro_recall_class": metrics["recall_macro_class"],
        "macro_f1_class": metrics["f1_macro_class"],

        # --- Macro theo aspect ---
        "macro_precision_aspect": metrics["precision_macro_aspect"],
        "macro_recall_aspect": metrics["recall_macro_aspect"],
        "macro_f1_aspect": metrics["f1_macro_aspect"],
    }

    # --- Thêm kết quả chi tiết từng aspect ---
    for aspect, scores in metrics["per_aspect"].items():
        result[f"{aspect}_precision_micro"] = scores["precision_micro"]
        result[f"{aspect}_recall_micro"] = scores["recall_micro"]
        result[f"{aspect}_f1_micro"] = scores["f1_micro"]
        result[f"{aspect}_precision_macro"] = scores["precision_macro_class"]
        result[f"{aspect}_recall_macro"] = scores["recall_macro_class"]
        result[f"{aspect}_f1_macro"] = scores["f1_macro_class"]

    return result

# %% [markdown]
# # Train

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from peft import LoraConfig, get_peft_model

model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# model.resize_token_embeddings(len(tokenizer))
# # LoRA config
# lora_config = LoraConfig(
#     r=8,                  # rank của LoRA, nhỏ = tiết kiệm VRAM hơn
#     lora_alpha=16,
#     target_modules=[
#         "q_proj", "v_proj",  # attention
#         # "k_proj", 
#         # "out_proj",  # bổ sung key và output
#         # "fc1", "fc2"          # feed-forward layers
#     ],
#     lora_dropout=0.05,
#     bias="none",
#     task_type="SEQ_2_SEQ_LM"
# )

# model = get_peft_model(model, lora_config)

# print(f"Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]

# %%
from transformers import GenerationConfig


training_args = Seq2SeqTrainingArguments(
    output_dir="bart-large-lora",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps = 4,
    weight_decay=0.03,
    save_total_limit=2,               
    num_train_epochs=15,
    generation_max_length=30,
    predict_with_generate=True,
    fp16=False,
    push_to_hub=True,
    logging_dir="./logs",
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="eval_macro_f1_class",  
    greater_is_better=True,            
    report_to=["wandb"],
)


gen_config = GenerationConfig(
    min_length=20,
    max_length=25,
    num_beams=4,        # nếu bạn muốn beam search
    do_sample=False,    # greedy search
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# Gán config sau khi tạo trainer
trainer.generation_config = gen_config

print(f"Kiểm tra min_length trước khi train: {trainer.generation_config.min_length}")
print(f"Kiểm tra max_length trước khi train: {trainer.generation_config.max_length}")

trainer.train()

# Evaluate on test set for final performance
test_results = trainer.evaluate(eval_dataset=tokenized_data["test"])
print("Final Test Results:", test_results)
# Out:
# <ipython-input-12-f531958bf6f7>:35: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# Kiểm tra min_length trước khi train: 20
# Kiểm tra max_length trước khi train: 25
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# {'loss': 2.2081, 'grad_norm': 39.0703239440918, 'learning_rate': 1.993558776167472e-05, 'epoch': 0.04819277108433735}
# {'loss': 0.9985, 'grad_norm': 104.88201141357422, 'learning_rate': 1.987117552334944e-05, 'epoch': 0.0963855421686747}
# {'loss': 0.8573, 'grad_norm': 24.257862091064453, 'learning_rate': 1.9806763285024154e-05, 'epoch': 0.14457831325301204}
# {'loss': 0.7586, 'grad_norm': 43.55107879638672, 'learning_rate': 1.9742351046698876e-05, 'epoch': 0.1927710843373494}
# {'loss': 0.7392, 'grad_norm': 44.766380310058594, 'learning_rate': 1.9677938808373592e-05, 'epoch': 0.24096385542168675}
# {'loss': 0.6894, 'grad_norm': 15.311283111572266, 'learning_rate': 1.961352657004831e-05, 'epoch': 0.2891566265060241}
# {'loss': 0.6293, 'grad_norm': 63.654598236083984, 'learning_rate': 1.954911433172303e-05, 'epoch': 0.3373493975903614}
# {'loss': 0.5777, 'grad_norm': 53.383522033691406, 'learning_rate': 1.9484702093397748e-05, 'epoch': 0.3855421686746988}
# {'loss': 0.5297, 'grad_norm': 21.48513412475586, 'learning_rate': 1.9420289855072467e-05, 'epoch': 0.43373493975903615}
# {'loss': 0.4914, 'grad_norm': 36.60835647583008, 'learning_rate': 1.9355877616747182e-05, 'epoch': 0.4819277108433735}
# {'loss': 0.4761, 'grad_norm': 104.73688507080078, 'learning_rate': 1.92914653784219e-05, 'epoch': 0.5301204819277109}
# {'loss': 0.4609, 'grad_norm': 126.68034362792969, 'learning_rate': 1.922705314009662e-05, 'epoch': 0.5783132530120482}
# {'loss': 0.4403, 'grad_norm': 47.19694519042969, 'learning_rate': 1.9162640901771338e-05, 'epoch': 0.6265060240963856}
# {'loss': 0.3963, 'grad_norm': 11.416614532470703, 'learning_rate': 1.9098228663446057e-05, 'epoch': 0.6746987951807228}
# {'loss': 0.3797, 'grad_norm': 70.15719604492188, 'learning_rate': 1.9033816425120775e-05, 'epoch': 0.7228915662650602}
# {'loss': 0.382, 'grad_norm': 47.50661087036133, 'learning_rate': 1.8969404186795494e-05, 'epoch': 0.7710843373493976}
# {'loss': 0.3483, 'grad_norm': 52.34587097167969, 'learning_rate': 1.890499194847021e-05, 'epoch': 0.8192771084337349}
# {'loss': 0.344, 'grad_norm': 25.427274703979492, 'learning_rate': 1.8840579710144928e-05, 'epoch': 0.8674698795180723}
# {'loss': 0.3191, 'grad_norm': 14.276721000671387, 'learning_rate': 1.8776167471819647e-05, 'epoch': 0.9156626506024096}
# {'loss': 0.2863, 'grad_norm': 10.79921817779541, 'learning_rate': 1.8711755233494366e-05, 'epoch': 0.963855421686747}
# === First 5 pred_texts ===
# 1: appearance:1,aroma:None,palate:0,taste:0
# 2: appearance:1,aroma:0,palate:-1,taste:-1
# 3: appearance:0,aroma:None,palate:1,taste:0
# 4: appearance:-1,aroma:None,palate:0,taste:-1
# 5: appearance:1,aroma:None,palate:0,taste:1
#
# === First 5 label_texts ===
# 1: appearance:-1,aroma:None,palate:None,taste:-1
# 2: appearance:-1,aroma:1,palate:-1,taste:0
# 3: appearance:1,aroma:None,palate:None,taste:1
# 4: appearance:1,aroma:None,palate:1,taste:1
# 5: appearance:0,aroma:None,palate:None,taste:0
# {'eval_loss': 0
# {'loss': 0.0989, 'grad_norm': 28.356630325317383, 'learning_rate': 1.0595813204508858e-05, 'epoch': 7.019277108433735}
# {'loss': 0.0717, 'grad_norm': 5.168504238128662, 'learning_rate': 1.0531400966183577e-05, 'epoch': 7.067469879518073}
# {'loss': 0.0995, 'grad_norm': 18.58199119567871, 'learning_rate': 1.0466988727858294e-05, 'epoch': 7.11566265060241}
# {'loss': 0.0891, 'grad_norm': 13.011689186096191, 'learning_rate': 1.0402576489533012e-05, 'epoch': 7.163855421686747}
# {'loss': 0.0824, 'grad_norm': 14.523432731628418, 'learning_rate': 1.033816425120773e-05, 'epoch': 7.212048192771085}
# {'loss': 0.0783, 'grad_norm': 44.815120697021484, 'learning_rate': 1.0273752012882448e-05, 'epoch': 7.260240963855422}
# {'loss': 0.0768, 'grad_norm': 35.55210876464844, 'learning_rate': 1.0209339774557168e-05, 'epoch': 7.308433734939759}
# {'loss': 0.0818, 'grad_norm': 7.08958101272583, 'learning_rate': 1.0144927536231885e-05, 'epoch': 7.356626506024097}
# {'loss': 0.0853, 'grad_norm': 10.429895401000977, 'learning_rate': 1.0080515297906604e-05, 'epoch': 7.404819277108434}
# {'loss': 0.0789, 'grad_norm': 4.304411888122559, 'learning_rate': 1.0016103059581321e-05, 'epoch': 7.453012048192771}
# {'loss': 0.0862, 'grad_norm': 6.184252738952637, 'learning_rate': 9.95169082125604e-06, 'epoch': 7.501204819277109}
# {'loss': 0.0884, 'grad_norm': 48.88761520385742, 'learning_rate': 9.887278582930757e-06, 'epoch': 7.549397590361446}
# {'loss': 0.0967, 'grad_norm': 9.061031341552734, 'learning_rate': 9.822866344605476e-06, 'epoch': 7.597590361445783}
# {'loss': 0.0838, 'grad_norm': 3.8305001258850098, 'learning_rate': 9.758454106280194e-06, 'epoch': 7.64578313253012}
# {'loss': 0.0851, 'grad_norm': 18.315519332885742, 'learning_rate': 9.694041867954911e-06, 'epoch': 7.693975903614458}
# {'loss': 0.0847, 'grad_norm': 6.569607257843018, 'learning_rate': 9.62962962962963e-06, 'epoch': 7.742168674698795}
# {'loss': 0.0847, 'grad_norm': 4.566434383392334, 'learning_rate': 9.565217391304349e-06, 'epoch': 7.790361445783132}
# {'loss': 0.0804, 'grad_norm': 7.360132694244385, 'learning_rate': 9.500805152979067e-06, 'epoch': 7.83855421686747}
# {'loss': 0.0803, 'grad_norm': 8.882671356201172, 'learning_rate': 9.436392914653784e-06, 'epoch': 7.886746987951807}
# {'loss': 0.0831, 'grad_norm': 39.426002502441406, 'learning_rate': 9.371980676328503e-06, 'epoch': 7.934939759036144}
# {'loss': 0.0851, 'grad_norm': 57.31959533691406, 'learning_rate': 9.307568438003222e-06, 'epoch': 7.983132530120482}
# === First 5 pred_texts ===
# 1: appearance:-1,aroma:None,palate:1,taste:-1
# 2: appearance:-1,aroma:1,palate:0,taste:-1
# 3: appearance:0,aroma:None,palate:-1,taste:1
# 4: appearance:0,aroma:None,palate:1,taste:1
# 5: appearance:-1,aroma:None,palate:1,taste:-1
#
# === First 5 label_texts ===
# 1: appearance:-1,aroma:None,palate:None,taste:-1
# 2: appearance:-1,aroma:1,palate:-1,taste:0
# 3: appearance:1,aroma:None,palate:None,taste:1
# 4: appearance:1,aroma:None,palate:1,taste:1
# 5: appearance:0,aroma:None,palate:None,taste:0
# {'eval_loss': 0
# {'loss': 0.0629, 'grad_norm': 22.757232666015625, 'learning_rate': 6.602254428341386e-06, 'epoch': 10.0}
# === First 5 pred_texts ===
# 1: appearance:-1,aroma:None,palate:1,taste:-1
# 2: appearance:0,aroma:1,palate:-1,taste:0
# 3: appearance:0,aroma:None,palate:1,taste:0
# 4: appearance:0,aroma:None,palate:1,taste:1
# 5: appearance:-1,aroma:None,palate:1,taste:0
#
# === First 5 label_texts ===
# 1: appearance:-1,aroma:None,palate:None,taste:-1
# 2: appearance:-1,aroma:1,palate:-1,taste:0
# 3: appearance:1,aroma:None,palate:None,taste:1
# 4: appearance:1,aroma:None,palate:1,taste:1
# 5: appearance:0,aroma:None,palate:None,taste:0
# {'eval_loss': 0.2779700458049774, 'eval_micro_precision': 0.48627450980392156, 'eval_micro_recall': 0.5767441860465117, 'eval_micro_f1': 0.5276595744680851, 'eval_macro_precision_class': 0.5015315653613526, 'eval_macro_recall_class': 0.5798209300384295, 'eval_macro_f1_class': 0.5349007311495839, 'eval_macro_precision_aspect': 0.49731531503047444, 'eval_macro_recall_aspect': 0.5605701207793845, 'eval_macro_f1_aspect': 0.5194234925051311, 'eval_appearance_precision_micro': 0.5850340136054422, 'eval_appearance_recall_micro': 0.6209386281588448, 'eval_appearance_f1_micro': 0.6024518388791593, 'eval_appearance_precision_macro': 0.5939193766937669, 'eval_appearance_recall_macro': 0.632005499475379, 'eval_appearance_f1_macro': 0.6116672346977764, 'eval_aroma_precision_micro': 0.4340175953079179, 'eval_aroma_recall_micro': 0.5803921568627451, 'eval_aroma_f1_micro': 0.49664429530201354, 'eval_aroma_precision_macro': 0.4527915426669121, 'eval_aroma_recall_macro': 0.5703576864535768, 'eval_aroma_f1_macro': 0.5008694028627584, 'eval_palate_precision_micro': 0.2724014336917563, 'eval_palate_recall_micro': 0.42696629213483145, 'eval_palate_f1_micro': 0.33260393873085337, 'eval_palate_precision_macro': 0.3216347144918574, 'eval_palate_recall_macro': 0.4279121196096342, 'eval_palate_f1_macro': 0.3489750445632798, 'eval_taste_precision_micro': 0.6204986149584487, 'eval_taste_recall_micro': 0.6136986301369863, 'eval_taste_f1_micro': 0.6170798898071624, 'eval_taste_precision_macro': 0.6209156262693613, 'eval_taste_recall_macro': 0.6120051775789481, 'eval_taste_f1_macro': 0.6161822878967098, 'eval_runtime': 117.8589, 'eval_samples_per_second': 3.564, 'eval_steps_per_second': 0.891, 'epoch': 10.0}
# {'loss': 0.0616, 'grad_norm': 5.077001571655273, 'learning_rate': 6.537842190016104e-06, 'epoch': 10.048192771084338}
# {'loss': 0.0531, 'grad_norm': 34.64168167114258, 'learning_rate': 6.473429951690822e-06, 'epoch': 10.096385542168674}
# {'loss': 0.0659, 'grad_norm': 4.605671405792236, 'learning_rate': 6.40901771336554e-06, 'epoch': 10.144578313253012}
# ...
# {'loss': 0.0507, 'grad_norm': 8.921868324279785, 'learning_rate': 2.7375201288244767e-06, 'epoch': 12.886746987951808}
# {'loss': 0.0505, 'grad_norm': 51.79107666015625, 'learning_rate': 2.6731078904991954e-06, 'epoch': 12.934939759036144}
# {'loss': 0.0512, 'grad_norm': 8.627582550048828, 'learning_rate': 2.6086956521739132e-06, 'epoch': 12.983132530120482}
# === First 5 pred_texts ===
# 1: appearance:-1,aroma:None,palate:0,taste:-1
# 2: appearance:-1,aroma:1,palate:-1taste:1
# 3: appearance:0,aroma:None,palate:-1,taste:0
# 4: appearance:0,aroma:None,palate:1,taste:1
# 5: appearance:-1,aroma:None,palate:0,taste:-1
#
# === First 5 label_texts ===
# 1: appearance:-1,aroma:None,palate:None,taste:-1
# 2: appearance:-1,aroma:1,palate:-1,taste:0
# 3: appearance:1,aroma:None,palate:None,taste:1
# 4: appearance:1,aroma:None,palate:1,taste:1
# 5: appearance:0,aroma:None,palate:None,taste:0
# {'eval_loss': 0
# {'loss': 0.0366, 'grad_norm': 4.352924346923828, 'learning_rate': 1.964573268921095e-06, 'epoch': 13.462650602409639}
# {'loss': 0.0407, 'grad_norm': 4.584787368774414, 'learning_rate': 1.9001610305958135e-06, 'epoch': 13.510843373493977}
# {'loss': 0.0396, 'grad_norm': 5.729842185974121, 'learning_rate': 1.8357487922705318e-06, 'epoch': 13.559036144578313}
# {'loss': 0.0381, 'grad_norm': 14.184304237365723, 'learning_rate': 1.7713365539452498e-06, 'epoch': 13.60722891566265}
# {'loss': 0.0364, 'grad_norm': 46.71184539794922, 'learning_rate': 1.7069243156199681e-06, 'epoch': 13.655421686746989}
# {'loss': 0.0385, 'grad_norm': 36.01743698120117, 'learning_rate': 1.6425120772946862e-06, 'epoch': 13.703614457831325}
# {'loss': 0.0399, 'grad_norm': 8.052620887756348, 'learning_rate': 1.5780998389694045e-06, 'epoch': 13.751807228915663}
# {'loss': 0.033, 'grad_norm': 4.222750663757324, 'learning_rate': 1.5136876006441225e-06, 'epoch': 13.8}
# {'loss': 0.0373, 'grad_norm': 15.715407371520996, 'learning_rate': 1.4492753623188408e-06, 'epoch': 13.848192771084337}
# {'loss': 0.0281, 'grad_norm': 2.314561605453491, 'learning_rate': 1.3848631239935589e-06, 'epoch': 13.896385542168675}
# {'loss': 0.0361, 'grad_norm': 20.567983627319336, 'learning_rate': 1.3204508856682772e-06, 'epoch': 13.944578313253013}
# {'loss': 0.0381, 'grad_norm': 4.258070945739746, 'learning_rate': 1.2560386473429952e-06, 'epoch': 13.992771084337349}
# === First 5 pred_texts ===
# 1: appearance:-1,aroma:None,palate:0,taste:-1
# 2: appearance:-1,aroma:1,palate:0,taste:0
# 3: appearance:0,aroma:None,palate:-1,taste:0
# 4: appearance:0,aroma:None,palate:1,taste:1
# 5: appearance:-1,aroma:None,palate:0,taste:0
#
# === First 5 label_texts ===
# 1: appearance:-1,aroma:None,palate:None,taste:-1
# 2: appearance:-1,aroma:1,palate:-1,taste:0
# 3: appearance:1,aroma:None,palate:None,taste:1
# 4: appearance:1,aroma:None,palate:1,taste:1
# 5: appearance:0,aroma:None,palate:None,taste:0
# {'eval_loss': 0.28898659348487854, 'eval_micro_precision': 0.4884080370942813, 'eval_micro_recall': 0.587906976744186, 'eval_micro_f1': 0.5335584634867032, 'eval_macro_precision_class': 0.5001493846346877, 'eval_macro_recall_class': 0.5914506872283832, 'eval_macro_f1_class': 0.5402843585802788, 'eval_macro_precision_aspect': 0.4984088179799921, 'eval_macro_recall_aspect': 0.5625858833849541, 'eval_macro_f1_aspect': 0.5215078922572112, 'eval_appearance_precision_micro': 0.6097560975609756, 'eval_appearance_recall_micro': 0.631768953068592, 'eval_appearance_f1_micro': 0.6205673758865248, 'eval_appearance_precision_macro': 0.6229548412211997, 'eval_appearance_recall_macro': 0.6379753247223127, 'eval_appearance_f1_macro': 0.6298521279629824, 'eval_aroma_precision_micro': 0.4523809523809524, 'eval_aroma_recall_micro': 0.596078431372549, 'eval_aroma_f1_micro': 0.5143824027072758, 'eval_aroma_precision_macro': 0.4783008658008658, 'eval_aroma_recall_macro': 0.5772499631757254, 'eval_aroma_f1_macro': 0.5176719576719576, 'eval_palate_precision_micro': 0.2354948805460751, 'eval_palate_recall_micro': 0.38764044943820225, 'eval_palate_f1_micro': 0.
# === First 5 pred_texts ===
# 1: appearance:-1,aroma:None,palate:0,taste:-1
# 2: appearance:-1,aroma:1,palate:-1 andtaste:1
# 3: appearance:0,aroma:None,palate:-1,taste:0
# 4: appearance:0,aroma:None,palate:1,taste:1
# 5: appearance:-1,aroma:None,palate:1,taste:-1
#
# === First 5 label_texts ===
# 1: appearance:-1,aroma:None,palate:None,taste:-1
# 2: appearance:-1,aroma:1,palate:-1,taste:0
# 3: appearance:1,aroma:None,palate:None,taste:1
# 4: appearance:1,aroma:None,palate:1,taste:1
# 5: appearance:0,aroma:None,palate:None,taste:0
# {'eval_loss': 0.2986443340778351, 'eval_micro_precision': 0.4953271028037383, 'eval_micro_recall': 0.5916279069767442, 'eval_micro_f1': 0.5392115303094531, 'eval_macro_precision_class': 0.501910816814343, 'eval_macro_recall_class': 0.5957189541473308, 'eval_macro_f1_class': 0.5443433296998715, 'eval_macro_precision_aspect': 0.49741200202044855, 'eval_macro_recall_aspect': 0.5700232397837967, 'eval_macro_f1_aspect': 0.5249040817120325, 'eval_appearance_precision_micro': 0.5924657534246576, 'eval_appearance_recall_micro': 0.6245487364620939, 'eval_appearance_f1_micro': 0.6080843585237259, 'eval_appearance_precision_macro': 0.6045751633986928, 'eval_appearance_recall_macro': 0.6339954412243569, 'eval_appearance_f1_macro': 0.6188651218062983, 'eval_aroma_precision_micro': 0.46407185628742514, 'eval_aroma_recall_micro': 0.6078431372549019, 'eval_aroma_f1_micro': 0.5263157894736842, 'eval_aroma_precision_macro': 0.48789320644990747, 'eval_aroma_recall_macro': 0.5863934305494182, 'eval_aroma_f1_macro': 0.5269081961243053, 'eval_palate_precision_micro': 0.26223776223776224, 'eval_palate_recall_micro': 0.42134831460674155, 'eval_palate_f1_micro': 0.3232758620689655, 'eval_palate_precision_macro': 0.27611638775817876, 'eval_palate_recall_macro': 0.42467669823566173, 'eval_palate_f1_macro': 0.3269358369513539, 'eval_taste_precision_micro': 0.6263440860215054, 'eval_taste_recall_micro': 0.6383561643835617, 'eval_taste_f1_micro': 0.6322930800542741, 'eval_taste_precision_macro': 0.6210632504750152, 'eval_taste_recall_macro': 0.6350273891257497, 'eval_taste_f1_macro': 0.6269071719661726, 'eval_runtime': 119.3175, 'eval_samples_per_second': 3.52, 'eval_steps_per_second': 0.88, 'epoch': 14.93012048192771}
# {'train_runtime': 13332.7257, 'train_samples_per_second': 3.735, 'train_steps_per_second': 0.233, 'train_loss': 0.14077699907639946, 'epoch': 14.93012048192771}
# No files have been modified since last commit. Skipping to prevent empty commit.
# === First 5 pred_texts ===
# 1: appearance:0,aroma:-1,palate:1,taste:1
# 2: appearance:-1,aroma:None,palate:1,taste:-1
# 3: appearance:0,aroma:-1,palate:None,taste:-1
# 4: appearance:0,aroma:-1,palate:None,taste:-1
# 5: appearance:1,aroma:None,palate:0,taste:0
#
# === First 5 label_texts ===
# 1: appearance:0,aroma:-1,palate:0,taste:1
# 2: appearance:0,aroma:None,palate:None,taste:-1
# 3: appearance:0,aroma:-1,palate:None,taste:-1
ate_f1_micro': 0.3445544554455445, 'eval_palate_precision_macro': 0.2790270607394061, 'eval_palate_recall_macro': 0.4907502962198525, 'eval_palate_f1_macro': 0.35062081258835825, 'eval_taste_precision_micro': 0.6191709844559585, 'eval_taste_recall_micro': 0.6373333333333333, 'eval_taste_f1_micro': 0.6281208935611038, 'eval_taste_precision_macro': 0.6193416624738832, 'eval_taste_recall_macro': 0.6475471975471976, 'eval_taste_f1_macro': 0.6316000128041572, 'eval_runtime': 115.5476, 'eval_samples_per_second': 3.548, 'eval_steps_per_second': 0.891, 'epoch': 14.93012048192771}

# %%
from peft import PeftModel

# Lấy model tốt nhất
best_model = trainer.model

# # Merge LoRA vào model gốc
# best_model = best_model.merge_and_unload()

# # Tạo thư mục mới chỉ để lưu model đã merge
# merge_dir = "Xcom-after-relabeled/bart-large-lora-om"
# best_model.save_pretrained(merge_dir, safe_serialization=True)
# tokenizer.save_pretrained(merge_dir)

# Push thư mục này lên Hugging Face
best_model.push_to_hub("lengocquangLAB/bart-large-lora-om", repo_type="model")
tokenizer.push_to_hub("lengocquangLAB/bart-large-lora-om", repo_type="model")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/lengocquangLAB/bart-large-lora-om/commit/a05d8f30939ae7f8166f6d7c5a8af9d6b5da74dc', commit_message='Upload tokenizer', commit_description='', oid='a05d8f30939ae7f8166f6d7c5a8af9d6b5da74dc', pr_url=None, repo_url=RepoUrl('https://huggingface.co/lengocquangLAB/bart-large-lora-om', endpoint='https://huggingface.co', repo_type='model', repo_id='lengocquangLAB/bart-large-lora-om'), pr_revision=None, pr_num=None)

# %% [markdown]
# # Evaluate

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

# Khai báo arguments cho trainer (không cần train, chỉ để eval)
training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    per_device_eval_batch_size=16,
    predict_with_generate=True,
    do_train=False,
    do_eval=True,
    logging_dir="./logs",
)

# Tạo trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,  # hàm bạn đã viết
    eval_dataset=tokenized_data["test"],
)

# Chạy evaluate
results = trainer.evaluate(eval_dataset=tokenized_data["test"])
print("Evaluation results:", results)
# Out:
# <ipython-input-14-f714e0f3cc70>:14: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# === First 5 pred_texts ===
# 1: appearance:0,aroma:-1,palate:1,taste
# 2: appearance:-1,aroma:None,palate:1,taste
# 3: appearance:0,aroma:-1,palate:None,taste:-
# 4: appearance:0,aroma:-1,palate:None,taste:-
# 5: appearance:1,aroma:None,palate:0,taste
#
# === First 5 label_texts ===
# 1: appearance:0,aroma:-1,palate:0,taste:1
# 2: appearance:0,aroma:None,palate:None,taste:-1
# 3: appearance:0,aroma:-1,palate:None,taste:-1
# 4: appearance:0,aroma:-1,palate:None,taste:-1
# 5: appearance:1,aroma:None,palate:None,taste:0
